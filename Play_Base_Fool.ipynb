# %% [markdown]
# <a href="https://colab.research.google.com/github/Mike030668/Base_Fool/blob/main/Play_Base_Fool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Mike030668/Base_Fool/
# Out:
# Cloning into 'Base_Fool'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 45 (delta 9), reused 37 (delta 8), pack-reused 0
# Receiving objects: 100% (45/45), 20.38 KiB | 485.00 KiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
from Base_Fool.BaseFool import Durack

# %% [markdown]
# # Задаем тип игры

# %%
# Инициализация игры
game = Durack(6,0,2)
gaimers, playcoloda, kozir = game.init_game()

# Запуск игрового цикла
game.go_game(gaimers, playcoloda, kozir)
# Out:
# Расcаживаем игроков в случайном порядке
# ['Robot_2(min)', 'Robot_1(min)']
# rand - робот со случайным выбором из возможных для хода карт
# min - робот выбирает минимальную из возможных для хода карт
#
# Сдаем карты:
# Выдача карт Robot_2(min)
# Выдача карт Robot_1(min)
#
# Козырь игры Крести
#
# cickle  1
# Robot_2(min) сделал ход Буби_9
# Выдача карт Robot_2(min)
# Игрок Robot_1(min) бьет картой Буби_Туз
# Выдача карт Robot_1(min)
# Robot_1(min) сделал ход Пики_7
# Выдача карт Robot_1(min)
#
# cickle  2
# Игрок Robot_2(min) бьет картой Пики_Валет
# Выдача карт Robot_2(min)
# Robot_2(min) сделал ход Черви_10
# Выдача карт Robot_2(min)
# Игрок Robot_1(min) бьет картой Черви_Валет
# Выдача карт Robot_1(min)
# Robot_1(min) сделал ход Пики_8
# Выдача карт Robot_1(min)
#
# cickle  3
# Игрок Robot_2(min) бьет картой Пики_Король
# Выдача карт Robot_2(min)
# Robot_2(min) сделал ход Черви_7
# Выдача карт Robot_2(min)
# Игрок Robot_1(min) бьет картой Черви_Дама
# Выдача карт Robot_1(min)
# ...

# %% [markdown]
# # Или отвечаем на опрос о типе игры

# %%
# Инициализация игры
game = Durack()
gaimers, playcoloda, kozir = game.init_game()

# Запуск игрового цикла
game.go_game(gaimers, playcoloda, kozir)
# Out:
# Укажите количество карт выдаваемых на руки от 2 до 6 включительно: 6
# Количество участников (роботы и люди) должно быть в сумме не менее 2 и не более 6
# Введите количество игроков людей: 0
# Введите количество игроков роботов: 2
#
# Расcаживаем игроков в случайном порядке
# ['Robot_1(min)', 'Robot_2(min)']
# rand - робот со случайным выбором из возможных для хода карт
# min - робот выбирает минимальную из возможных для хода карт
#
# Сдаем карты:
# Выдача карт Robot_1(min)
# Выдача карт Robot_2(min)
#
# Козырь игры Буби
#
# cickle  1
# Robot_1(min) сделал ход Черви_8
# Выдача карт Robot_1(min)
# Игрок Robot_2(min) бьет картой Черви_Туз
# Выдача карт Robot_2(min)
# Robot_2(min) сделал ход Черви_6
# Выдача карт Robot_2(min)
#
# cickle  2
# Игрок Robot_1(min) бьет картой Черви_9
# Выдача карт Robot_1(min)
# Robot_1(min) сделал ход Пики_6
# Выдача карт Robot_1(min)
# Игрок Robot_2(min) бьет картой Пики_Король
# Выдача карт Robot_2(min)
# Robot_2(min) сделал ход Крести_6
# ...
